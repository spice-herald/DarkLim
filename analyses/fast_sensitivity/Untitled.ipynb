# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import fast_inference as fi

# %%
fig = fi.FastInference_GaAs(constant_file="gaas_defaults.yaml", nexp=100)

# %%
fig.process_inference()
# Out:
# Starting the loop over 1 dark matter masses with 100 pseudoexperiments each
# In the first pseudoexperiment for mass 10.0 GeV, we simulated 60679 events
# On mass 1 of 1. E_high is 1186.974 eV, E_low is 5.000 eV.
# Total integrated rate for mass 10.0 GeV: 5.000e-01 events.
# Optimum interval for mass 10.0 GeV: [297.079, 913.925] eV
# Endpoints: 60287, 60553. UL output: 449.391 events
# Cross section upper limit for mass 10.0 GeV: 8.988e-41 cm^2
# For masses [10.0], the median limits are: [8.39703283e-41]
# array([8.39703283e-41])

# %%
fis = fi.FastInference_Al2O3(constant_file="al2o3_defaults.yaml", nexp = 100)

# %%
fig.process_inference()
# Out:
# Starting the loop over 1 dark matter masses with 100 pseudoexperiments each
# In the first pseudoexperiment for mass 10.0 GeV, we simulated 60523 events
# On mass 1 of 1. E_high is 1187.351 eV, E_low is 5.000 eV.
# Total integrated rate for mass 10.0 GeV: 4.999e-01 events.
# Optimum interval for mass 10.0 GeV: [369.184, 950.484] eV
# Endpoints: 60212, 60433. UL output: 408.811 events
# Cross section upper limit for mass 10.0 GeV: 8.178e-41 cm^2
# For masses [10.0], the median limits are: [8.40286649e-41]
# array([8.40286649e-41])

# %%
fih = fi.FastInference_He(constant_file="he_defaults.yaml", nexp = 100)

# %%
fih.process_inference()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 fih.process_inference()
#
# File ~/software/DarkLim/analyses/fast_sensitivity/fast_inference.py:251, in FastInference_He.process_inference(self)
#     245 #SE.add_nfold_lee_bkgd(m=args.n_sensors, n=args.coincidence, w=args.window_s, e0=0.41e-3, R=33.)
#     246 #SE.add_nfold_lee_bkgd(m=args.n_sensors, n=args.coincidence, w=args.window_s, e0=3.81e-3, R=0.0226)
#     247 #SE.add_power_bkgd(1.4e-8, 5.77)
#     248 #SE.add_power_bkgd(0.107, 2.72)
#     250 SE.add_flat_bkgd(self.parameters["flat_rate_DRU"])
# --> 251 SE.add_nfold_powerlaw_lee_bkgd(m=self.parameters["n_sensors"],
#     252                                                  n=self.parameters["coincidence"],
#     253                                                  w=self.parameters["window_s"])
#     255 per_device_threshold_keV = self.parameters["nsigma"] * self.parameters["baseline_res_eV"] * 1e-3
#     256 threshold_keV = self.parameters["coincidence"] * per_device_threshold_keV
#
# File ~/data/conda/envs/pytes2/lib/python3.10/site-packages/darklim/sensitivity/_sens_est.py:367, in SensEst.add_nfold_powerlaw_lee_bkgd(self, m, n, w)
#     353 """
#     354 Method for adding n-fold coincidence bkg assuming
#     355 power-law distributed LEE. loads in pregenerated templates.
#    (...)
#     364     Coincidence window length in seconds.
#     365 """
#     366 fin = '/global/cfs/cdirs/lz/users/haselsco/TESSERACT_Limits/DarkLim_vetriupdate/examples/LEE_templates/LEE_bkg_{:d}device_{:d}fold_{:0.0f}mus.txt'.format(m,n,w/1e-6)
# --> 367 template = np.loadtxt(fin,skiprows=1)
#     368 interp_func = interp1d(template[:,0],template[:,1],
#     369                        fill_value='extrapolate',
#     370                        assume_sorted=True)
#     372 nfold_power_lee = lambda x: interp_func(x) / self.m_det
#
# File ~/data/conda/envs/pytes2/lib/python3.10/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File ~/data/conda/envs/pytes2/lib/python3.10/site-packages/numpy/lib/npyio.py:992, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990     fname = os.fspath(fname)
#     991 if isinstance(fname, str):
# --> 992     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993     if encoding is None:
#     994         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/data/conda/envs/pytes2/lib/python3.10/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/data/conda/envs/pytes2/lib/python3.10/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: /global/cfs/cdirs/lz/users/haselsco/TESSERACT_Limits/DarkLim_vetriupdate/examples/LEE_templates/LEE_bkg_4device_4fold_100mus.txt not found.
